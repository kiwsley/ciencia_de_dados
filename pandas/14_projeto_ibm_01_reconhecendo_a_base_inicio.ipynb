# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %% [markdown]
# ## Checagens básicas

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
import pandas as pd
dados = pd.read_csv("dados/employee_attrition.csv")
dados.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
with pd.option_context("display.max_columns",35):
    display(dados.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
dados.shape
# Out:
# (1470, 35)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
with pd.option_context("float_format", "{:.2f}".format, "display.max.columns",35):
    display(dados.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# min              1.00                     1.00       30.00            1.00
# 25%            491.25                     2.00       48.00            2.00
# 50%           1020.50                     3.00       66.00            3.00
# 75%           1555.75                     4.00       83.75            3.00
# max           2068.00                     4.00      100.00            4.00
#
#        JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# count   1470.00          1470.00        1470.00      1470.00
# mean       2.06             2.73        6502.93     14313.10
# std        1.11             1.10        4707.96      7117.79
# min        1.00             1.00        1009.00      2094.00
# 25%        1.00             2.00        2911.00      8047.00
# 50%        2.00             3.00        4919.00     14235.50
# 75%        3.00             4.00        8379.00     20461.50
# max        5.00             4.00       19999.00     26999.00
#
#        NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count             1470.00            1470.00            1470.00
# mean                 2.69              15.21               3.15
# std                  2.50               3.66               0.36
# min                  0.00              11.00               3.00
# 25%                  1.00              12.00               3.00
# 50%                  2.00              14.00               3.00
# 75%                  4.00              18.00               3.00
# max                  9.00              25.00               4.00
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count                   1470.00        1470.00           1470.00
# mean                       2.71          80.00              0.79
# std                        1.08           0.00              0.85
# min                        1.00          80.00              0.00
# 25%                        2.00          80.00              0.00
# 50%                        3.00          80.00              1.00
# 75%                        4.00          80.00              1.00
# max                        4.00          80.00              3.00
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count            1470.00                1470.00          1470.00
# mean               11.28                   2.80             2.76
# std                 7.78                   1.29             0.71
# min                 0.00                   0.00             1.00
# 25%                 6.00                   2.00             2.00
# 50%                10.00                   3.00             3.00
# 75%                15.00                   3.00             3.00
# max                40.00                   6.00             4.00
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count         1470.00             1470.00                  1470.00
# mean             7.01                4.23                     2.19
# std              6.13                3.62                     3.22
# min              0.00                0.00                     0.00
# 25%              3.00                2.00                     0.00
# 50%              5.00                3.00                     1.00
# 75%              9.00                7.00                     3.00
# max             40.00               18.00                    15.00
#
#        YearsWithCurrManager
# count               1470.00
# mean                   4.12
# std                    3.57
# min                    0.00
# 25%                    2.00
# 50%                    3.00
# 75%                    7.00
# max                   17.00

# %%
dados.describe(exclude="number")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
dados.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
dados.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exercícios
#
# - remover colunas com valores únicos
# - encontrar os registros dos 10 funcionários mais velhos e dos 10 mais novos
# - encontrar os registros dos 10 funcionários com mais tempo de empresa e dos 10 com menos tempo
# - encontrar os registros dos 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo
# - agrupamentos (em cada caso, mostrar também o agrupamento por saída ou não do funcionário)
#   - contagem de funcionários por departamento
#   - média de salário por departamento
#   - gênero por departamento
#   - gênero por cargo
#   - média de salário por cargo
#   - média de salário por cargo e nível
#   - contagem de gênero por departamento
#   - média de salário por nível educacional

# %%
dados.drop(columns=['Over18','EmployeeCount','StandardHours','EmployeeNumber'])
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# 1                    8          1  Life Sciences                        3
# 2                    2          2          Other                        4
# 3                    3          4  Life Sciences                        4
# 4                    2          1        Medical                        1
# ...                ...        ...            ...                      ...
# 1465                23          2        Medical                        3
# 1466                 6          1        Medical                        4
# 1467                 4          3  Life Sciences                        2
# 1468                 2          3        Medical                        4
# 1469                 8          3        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0     Female  ...                  3                         1
# 1       Male  ...                  4                         4
# 2       Male  ...                  3                         2
# 3     Female  ...                  3                         3
# 4       Male  ...                  3                         4
# ...      ...  ...                ...                       ...
# 1465    Male  ...                  3                         3
# 1466    Male  ...                  3                         1
# 1467    Male  ...                  4                         2
# 1468    Male  ...                  3                         4
# 1469    Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                 8                      0
# 1                    1                10                      3
# 2                    0                 7                      3
# 3                    0                 8                      3
# 4                    1                 6                      3
# ...                ...               ...                    ...
# 1465                 1                17                      3
# 1466                 1                 9                      5
# 1467                 1                 6                      0
# 1468                 0                17                      3
# 1469                 0                 6                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  1               6                   4
# 1                  3              10                   7
# 2                  3               0                   0
# 3                  3               8                   7
# 4                  3               2                   2
# ...              ...             ...                 ...
# 1465               3               5                   2
# 1466               3               7                   7
# 1467               3               6                   2
# 1468               2               9                   6
# 1469               4               4                   3
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 0                           0                    5
# 1                           1                    7
# 2                           0                    0
# 3                           3                    0
# 4                           2                    2
# ...                       ...                  ...
# 1465                        0                    3
# 1466                        1                    7
# 1467                        0                    3
# 1468                        0                    8
# 1469                        1                    2
#
# [1470 rows x 31 columns]

# %%
dados.nlargest(10,'Age')
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 411                  7          3    Life Sciences              1
# 427                 28          3        Marketing              1
# 536                 16          4        Marketing              1
# 879                  7          4        Marketing              1
# 1209                 1          4          Medical              1
# 6                    3          3          Medical              1
# 63                  25          3    Life Sciences              1
# 70                   1          1    Life Sciences              1
# 105                  2          4  Human Resources              1
# 225                  3          3    Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 411              549  ...                         4            80
# 427              573  ...                         4            80
# 536              732  ...                         4            80
# 879             1233  ...                         2            80
# 1209            1697  ...                         3            80
# 6                 10  ...                         1            80
# 63                81  ...                         4            80
# 70                91  ...                         4            80
# 105              140  ...                         4            80
# 225              309  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                 33                      5
# 427                  0                 22                      5
# 536                  0                 10                      1
# 879                  1                 12                      3
# 1209                 1                 19                      2
# 6                    3                 12                      3
# 63                   0                 28                      3
# 70                   0                 20                      2
# 105                  1                 30                      3
# 225                  1                  7                      6
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 411                1              29                  8
# 427                4              18                 13
# 536                3               2                  2
# 879                3              11                  7
# 1209               4               1                  0
# 6                  2               1                  0
# 63                 2              21                 16
# 70                 2               4                  3
# 105                3               3                  2
# 225                3               1                  0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 411                        11                    10
# 427                        13                    11
# 536                         2                     2
# 879                         1                     9
# 1209                        0                     0
# 6                           0                     0
# 63                          7                     9
# 70                          1                     3
# 105                         2                     2
# 225                         0                     0
#
# [10 rows x 35 columns]

# %%
dados.nsmallest(10,"Age")
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 296                  3          3  Life Sciences              1
# 301                 10          3        Medical              1
# 457                  5          3      Marketing              1
# 727                  5          2  Life Sciences              1
# 828                  8          1        Medical              1
# 972                  1          3  Life Sciences              1
# 1153                 3          2        Medical              1
# 1311                14          3        Medical              1
# 127                 22          1      Marketing              1
# 149                  3          1        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 296              405  ...                         3            80
# 301              411  ...                         1            80
# 457              614  ...                         4            80
# 727             1012  ...                         4            80
# 828             1156  ...                         4            80
# 972             1368  ...                         3            80
# 1153            1624  ...                         3            80
# 1311            1839  ...                         3            80
# 127              167  ...                         4            80
# 149              201  ...                         4            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 296                  0                  0                      2
# 301                  0                  0                      2
# 457                  0                  0                      3
# 727                  0                  0                      2
# 828                  0                  0                      0
# 972                  0                  0                      5
# 1153                 0                  0                      2
# 1311                 0                  0                      4
# 127                  0                  0                      2
# 149                  0                  1                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 296                3               0                  0
# 301                3               0                  0
# 457                3               0                  0
# 727                3               0                  0
# 828                3               0                  0
# 972                4               0                  0
# 1153               4               0                  0
# 1311               1               0                  0
# 127                2               0                  0
# 149                3               1                  0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 296                         0                     0
# 301                         0                     0
# 457                         0                     0
# 727                         0                     0
# 828                         0                     0
# 972                         0                     0
# 1153                        0                     0
# 1311                        0                     0
# 127                         0                     0
# 149                         0                     0
#
# [10 rows x 35 columns]

# %%
dados.nlargest(10,'YearsAtCompany')
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 126                 23          4           Medical              1
# 98                  10          4           Medical              1
# 270                  1          3           Medical              1
# 1116                26          5         Marketing              1
# 561                  3          4         Marketing              1
# 190                  1          4     Life Sciences              1
# 237                  2          4     Life Sciences              1
# 914                  8          1           Medical              1
# 962                  5          3     Life Sciences              1
# 1111                 2          5  Technical Degree              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 126              165  ...                         4            80
# 98               131  ...                         3            80
# 270              374  ...                         3            80
# 1116            1578  ...                         3            80
# 561              776  ...                         1            80
# 190              259  ...                         1            80
# 237              329  ...                         4            80
# 914             1278  ...                         4            80
# 962             1352  ...                         2            80
# 1111            1572  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 126                  1                 40                      3
# 98                   0                 38                      1
# 270                  0                 37                      2
# 1116                 1                 36                      3
# 561                  0                 34                      3
# 190                  1                 34                      5
# 237                  0                 33                      2
# 914                  1                 34                      3
# 962                  1                 33                      2
# 1111                 1                 34                      4
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 126                2              40                 10
# 98                 2              37                 10
# 270                3              36                 10
# 1116               3              36                  6
# 561                4              34                  6
# 190                3              33                 18
# 237                4              33                  7
# 914                3              33                  9
# 962                3              33                  9
# 1111               3              33                  7
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 126                        15                     6
# 98                          1                     8
# 270                         4                    13
# 1116                        2                    13
# 561                         1                    16
# 190                        11                     9
# 237                        15                    12
# 914                        15                     0
# 962                         0                    10
# 1111                        1                     9
#
# [10 rows x 35 columns]

# %%
dados.nsmallest(10,"YearsAtCompany")
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 23    21        No      Travel_Rarely        391  Research & Development
# 77    45        No      Travel_Rarely        193  Research & Development
# 86    23        No      Travel_Rarely        541                   Sales
# 109   22        No      Travel_Rarely        534  Research & Development
# 127   19       Yes      Travel_Rarely        528                   Sales
# 171   19       Yes  Travel_Frequently        602                   Sales
# 264   28       Yes      Travel_Rarely        529  Research & Development
# 265   29        No      Travel_Rarely       1210                   Sales
# 296   18       Yes      Travel_Rarely        230  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 2                   2          2             Other              1
# 23                 15          2     Life Sciences              1
# 77                  6          4             Other              1
# 86                  2          1  Technical Degree              1
# 109                15          3           Medical              1
# 127                22          1         Marketing              1
# 171                 1          1  Technical Degree              1
# 264                 2          4     Life Sciences              1
# 265                 2          3           Medical              1
# 296                 3          3     Life Sciences              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 2                 4  ...                         2            80
# 23               30  ...                         4            80
# 77              101  ...                         2            80
# 86              113  ...                         3            80
# 109             144  ...                         3            80
# 127             167  ...                         4            80
# 171             235  ...                         1            80
# 264             364  ...                         3            80
# 265             366  ...                         2            80
# 296             405  ...                         3            80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 2                   0                  7                      3
# 23                  0                  0                      6
# 77                  0                 17                      3
# 86                  1                  3                      3
# 109                 0                  1                      5
# 127                 0                  0                      2
# 171                 0                  1                      5
# 264                 0                  5                      5
# 265                 2                 10                      2
# 296                 0                  0                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 2                 3               0                  0
# 23                3               0                  0
# 77                4               0                  0
# 86                3               0                  0
# 109               3               0                  0
# 127               2               0                  0
# 171               4               0                  0
# 264               1               0                  0
# 265               3               0                  0
# 296               3               0                  0
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 2                          0                     0
# 23                         0                     0
# 77                         0                     0
# 86                         0                     0
# 109                        0                     0
# 127                        0                     0
# 171                        0                     0
# 264                        0                     0
# 265                        0                     0
# 296                        0                     0
#
# [10 rows x 35 columns]

# %%
dados.nlargest(10,'YearsSinceLastPromotion')
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 45                 12          3  Technical Degree              1
# 123                 6          3     Life Sciences              1
# 126                23          4           Medical              1
# 178                 1          2         Marketing              1
# 237                 2          4     Life Sciences              1
# 425                29          4     Life Sciences              1
# 701                 2          2           Medical              1
# 752                16          4     Life Sciences              1
# 861                 2          3         Marketing              1
# 914                 8          1           Medical              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 45               58  ...                         4            80
# 123             162  ...                         3            80
# 126             165  ...                         4            80
# 178             244  ...                         3            80
# 237             329  ...                         4            80
# 425             569  ...                         2            80
# 701             981  ...                         3            80
# 752            1042  ...                         3            80
# 861            1204  ...                         1            80
# 914            1278  ...                         4            80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 45                  0                 23                      0
# 123                 0                 23                      5
# 126                 1                 40                      3
# 178                 3                 24                      2
# 237                 0                 33                      2
# 425                 1                 28                      2
# 701                 1                 22                      3
# 752                 0                 18                      1
# 861                 0                 28                      2
# 914                 1                 34                      3
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 45                3              22                 15
# 123               3              20                 18
# 126               2              40                 10
# 178               3              24                 13
# 237               4              33                  7
# 425               3              27                 10
# 701               4              17                 13
# 752               3              17                 13
# 861               3              26                 15
# 914               3              33                  9
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 45                        15                     8
# 123                       15                    15
# 126                       15                     6
# 178                       15                     7
# 237                       15                    12
# 425                       15                     7
# 701                       15                     2
# 752                       15                    14
# 861                       15                     9
# 914                       15                     0
#
# [10 rows x 35 columns]

# %%
dados.nlargest(10,'YearsSinceLastPromotion')[['Age',"JobRole","YearsSinceLastPromotion","JobLevel"]]
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4

# %%
dados.nsmallest(10,'YearsSinceLastPromotion')[['Age',"JobRole","YearsSinceLastPromotion","JobLevel"]]
# Out:
#     Age                JobRole  YearsSinceLastPromotion  JobLevel
# 0    41        Sales Executive                        0         2
# 2    37  Laboratory Technician                        0         1
# 6    59  Laboratory Technician                        0         1
# 7    30  Laboratory Technician                        0         1
# 10   35  Laboratory Technician                        0         1
# 11   29  Laboratory Technician                        0         2
# 14   28  Laboratory Technician                        0         1
# 16   32     Research Scientist                        0         1
# 17   22  Laboratory Technician                        0         1
# 21   36   Sales Representative                        0         1

# %%
#analisando salarios

dados["MonthlyIncome"].nunique()
# Out:
# 1349

# %%
dados.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
colunas_categoricas_nao_ordenada = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "Gender",
    "JobRole",
    "MaritalStatus",
    "OverTime",
]

colunas_categoricas_ordenada =[
    "Education",
    "EnvironmentSatisfaction",
    "JobSatisfaction",
    "JobInvolvement",
    "JobLevel",
    "PerformanceRating",
    "RelationshipSatisfaction",
    "StockOptionLevel",
    "WorkLifeBalance"
]

coluna_alvo = ["Attrition"]
colunas_numerica =[ 
    coluna for coluna in dados.columns if coluna not in (
        colunas_categoricas_nao_ordenada + colunas_categoricas_ordenada+coluna_alvo
    )
    ]

# %%
colunas_numerica
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'PercentSalaryHike',
#  'StandardHours',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for coluna in (colunas_categoricas_nao_ordenada + colunas_categoricas_ordenada):
    print(f"{coluna}: {dados[coluna].unique()}")
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# EnvironmentSatisfaction: [2 3 4 1]
# JobSatisfaction: [4 2 3 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
for coluna in colunas_categoricas_nao_ordenada:
    dados[coluna]=dados[coluna].astype("category")

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   category
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   category
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   category
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   category
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(7), int64(26), object(2)
# memory usage: 332.9+ KB

# %%
dados["OverTime"].cat.ordered
# Out:
# False

# %%
for coluna in dados.select_dtypes(include="category"):
    print(f"{coluna}")
    print(f"{coluna}.cat.categories:{dados[coluna].cat.categories}")
    print(f"{coluna}.cat.ordered: {dados[coluna].cat.ordered}")
    print(f"{coluna}.cat.ordered: {dados[coluna].cat.codes.unique()}")
    print("------------------------------------------------------------------------")
# Out:
# BusinessTravel
# BusinessTravel.cat.categories:Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.ordered: [2 1 0]
# ------------------------------------------------------------------------
# Department
# Department.cat.categories:Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.ordered: [2 1 0]
# ------------------------------------------------------------------------
# EducationField
# EducationField.cat.categories:Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.ordered: [1 4 3 2 5 0]
# ------------------------------------------------------------------------
# Gender
# Gender.cat.categories:Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.ordered: [0 1]
# ------------------------------------------------------------------------
# JobRole
# JobRole.cat.categories:Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# JobRole.cat.ordered: False
# JobRole.cat.ordered: [7 6 2 4 0 3 8 5 1]
# ------------------------------------------------------------------------
# MaritalStatus
# MaritalStatus.cat.categories:Index(['Divorced', 'Married', 'Single'], dtype='object')
# MaritalStatus.cat.ordered: False
# MaritalStatus.cat.ordered: [2 1 0]
# ------------------------------------------------------------------------
# OverTime
# OverTime.cat.categories:Index(['No', 'Yes'], dtype='object')
# OverTime.cat.ordered: False
# OverTime.cat.ordered: [1 0]
# ------------------------------------------------------------------------

# %%
dados["Attrition"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Attrition'>

# %%
dados["Attrition"].value_counts(normalize=True).plot(kind='bar',color=['blue','red'])
# Out:
# <Axes: xlabel='Attrition'>

# %%
dados["Department"].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
dados.groupby(["Department","Attrition"]).size()
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2136108126.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby(["Department","Attrition"]).size()
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
dados.pivot_table(index="Department",columns="Attrition",aggfunc="size")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2454884513.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index="Department",columns="Attrition",aggfunc="size")
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
#CrossTab

pd.crosstab(dados["Department"], dados["Attrition"])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(dados["Department"], dados["Attrition"],normalize="index")
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
pd.crosstab(dados["Department"], dados["Attrition"],normalize="columns").style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_2fbd6_row0_col0, #T_2fbd6_row1_col1, #T_2fbd6_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2fbd6_row0_col1, #T_2fbd6_row1_col0, #T_2fbd6_row2_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2fbd6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_2fbd6_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_2fbd6_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fbd6_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_2fbd6_row0_col0" class="data row0 col0" >0.041363</td>
#       <td id="T_2fbd6_row0_col1" class="data row0 col1" >0.050633</td>
#     </tr>
#     <tr>
#       <th id="T_2fbd6_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_2fbd6_row1_col0" class="data row1 col0" >0.671533</td>
#       <td id="T_2fbd6_row1_col1" class="data row1 col1" >0.561181</td>
#     </tr>
#     <tr>
#       <th id="T_2fbd6_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_2fbd6_row2_col0" class="data row2 col0" >0.287105</td>
#       <td id="T_2fbd6_row2_col1" class="data row2 col1" >0.388186</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(dados["Department"], dados["Attrition"],normalize="index").style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_b78a1_row0_col0, #T_b78a1_row1_col0, #T_b78a1_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b78a1_row0_col1, #T_b78a1_row1_col1, #T_b78a1_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b78a1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_b78a1_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_b78a1_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b78a1_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_b78a1_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_b78a1_row0_col1" class="data row0 col1" >0.190476</td>
#     </tr>
#     <tr>
#       <th id="T_b78a1_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_b78a1_row1_col0" class="data row1 col0" >0.861602</td>
#       <td id="T_b78a1_row1_col1" class="data row1 col1" >0.138398</td>
#     </tr>
#     <tr>
#       <th id="T_b78a1_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_b78a1_row2_col0" class="data row2 col0" >0.793722</td>
#       <td id="T_b78a1_row2_col1" class="data row2 col1" >0.206278</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(dados["Department"], dados["Attrition"],margins=True,margins_name="Total")
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
pd.crosstab(dados["Department"], dados["Attrition"]).plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
dados.groupby("Department")["MonthlyIncome"].mean().plot(kind="bar")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\3151000516.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby("Department")["MonthlyIncome"].mean().plot(kind="bar")
# <Axes: xlabel='Department'>

# %%
dados.groupby(["Department","Attrition"])["MonthlyIncome"].mean()
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\3591854587.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby(["Department","Attrition"])["MonthlyIncome"].mean()
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
dados.pivot_table(index="Department",columns="Attrition",values="MonthlyIncome").style.background_gradient(cmap="RdYlGn",axis="columns")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\3909272539.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index="Department",columns="Attrition",values="MonthlyIncome").style.background_gradient(cmap="RdYlGn",axis="columns")
# <style type="text/css">
# #T_60094_row0_col0, #T_60094_row1_col0, #T_60094_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_60094_row0_col1, #T_60094_row1_col1, #T_60094_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_60094">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_60094_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_60094_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60094_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_60094_row0_col0" class="data row0 col0" >7345.980392</td>
#       <td id="T_60094_row0_col1" class="data row0 col1" >3715.750000</td>
#     </tr>
#     <tr>
#       <th id="T_60094_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_60094_row1_col0" class="data row1 col0" >6630.326087</td>
#       <td id="T_60094_row1_col1" class="data row1 col1" >4108.075188</td>
#     </tr>
#     <tr>
#       <th id="T_60094_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_60094_row2_col0" class="data row2 col0" >7232.240113</td>
#       <td id="T_60094_row2_col1" class="data row2 col1" >5908.456522</td>
#     </tr>
#   </tbody>
# </table>

# %%
dados.pivot_table(index="Department",columns="Attrition",values="MonthlyIncome").plot(kind="bar")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\1160458253.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index="Department",columns="Attrition",values="MonthlyIncome").plot(kind="bar")
# <Axes: xlabel='Department'>

# %%
dados.groupby("JobRole")["MonthlyIncome"].mean()
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\1220018701.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby("JobRole")["MonthlyIncome"].mean()
# JobRole
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: MonthlyIncome, dtype: float64

# %%
dados.groupby(["JobRole","JobLevel"])["MonthlyIncome"].mean()
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2144374880.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby(["JobRole","JobLevel"])["MonthlyIncome"].mean()
# JobRole                    JobLevel
# Healthcare Representative  1                    NaN
#                            2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
#                            5                    NaN
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
#                            4                    NaN
#                            5                    NaN
# Laboratory Technician      1            2854.590000
#                            2            4455.625000
#                            3            5998.000000
#                            4                    NaN
#                            5                    NaN
# Manager                    1                    NaN
#                            2                    NaN
#                            3           12233.000000
#                            4           16613.276596
#                            5           19183.976744
# Manufacturing Director     1                    NaN
#                            2            5612.755556
#                            3            9307.044444
#                            4           13383.000000
#                            5                    NaN
# Research Director          1                    NaN
#                            2                    NaN
#                            3           12721.571429
#                            4           16429.038462
#                            5           19204.807692
# Research Scientist         1            2827.649573
#                            2            4818.912281
#                            3            9724.000000
#                            4                    NaN
#                            5                    NaN
# Sales Executive            1                    NaN
#                            2            5800.884120
#                            3            9124.987342
#                            4           13202.500000
#                            5                    NaN
# Sales Representative       1            2506.723684
#                            2            3921.000000
#                            3                    NaN
#                            4                    NaN
#                            5                    NaN
# Name: MonthlyIncome, dtype: float64

# %%
dados.groupby(["JobRole","JobLevel"])["MonthlyIncome"].mean().to_frame().style.background_gradient(cmap="RdYlGn",axis="index")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2284120765.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby(["JobRole","JobLevel"])["MonthlyIncome"].mean().to_frame().style.background_gradient(cmap="RdYlGn",axis="index")
# <style type="text/css">
# #T_eea0e_row0_col0, #T_eea0e_row4_col0, #T_eea0e_row8_col0, #T_eea0e_row9_col0, #T_eea0e_row13_col0, #T_eea0e_row14_col0, #T_eea0e_row15_col0, #T_eea0e_row16_col0, #T_eea0e_row20_col0, #T_eea0e_row24_col0, #T_eea0e_row25_col0, #T_eea0e_row26_col0, #T_eea0e_row33_col0, #T_eea0e_row34_col0, #T_eea0e_row35_col0, #T_eea0e_row39_col0, #T_eea0e_row42_col0, #T_eea0e_row43_col0, #T_eea0e_row44_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_eea0e_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_eea0e_row2_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_eea0e_row3_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_eea0e_row5_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_eea0e_row6_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_eea0e_row7_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_eea0e_row10_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_eea0e_row11_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_eea0e_row12_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_eea0e_row17_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_eea0e_row18_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_eea0e_row19_col0, #T_eea0e_row29_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_eea0e_row21_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_eea0e_row22_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_eea0e_row23_col0 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_eea0e_row27_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_eea0e_row28_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_eea0e_row30_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_eea0e_row31_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_eea0e_row32_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_eea0e_row36_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_eea0e_row37_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_eea0e_row38_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_eea0e_row40_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_eea0e_row41_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eea0e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eea0e_level0_col0" class="col_heading level0 col0" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eea0e_level0_row0" class="row_heading level0 row0" rowspan="5">Healthcare Representative</th>
#       <th id="T_eea0e_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_eea0e_row0_col0" class="data row0 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_eea0e_row1_col0" class="data row1 col0" >5865.346154</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_eea0e_row2_col0" class="data row2 col0" >9363.954545</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_eea0e_row3_col0" class="data row3 col0" >12973.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_eea0e_row4_col0" class="data row4 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level0_row5" class="row_heading level0 row5" rowspan="5">Human Resources</th>
#       <th id="T_eea0e_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_eea0e_row5_col0" class="data row5 col0" >2733.212121</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row6" class="row_heading level1 row6" >2</th>
#       <td id="T_eea0e_row6_col0" class="data row6 col0" >5563.461538</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row7" class="row_heading level1 row7" >3</th>
#       <td id="T_eea0e_row7_col0" class="data row7 col0" >9623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_eea0e_row8_col0" class="data row8 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row9" class="row_heading level1 row9" >5</th>
#       <td id="T_eea0e_row9_col0" class="data row9 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level0_row10" class="row_heading level0 row10" rowspan="5">Laboratory Technician</th>
#       <th id="T_eea0e_level1_row10" class="row_heading level1 row10" >1</th>
#       <td id="T_eea0e_row10_col0" class="data row10 col0" >2854.590000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row11" class="row_heading level1 row11" >2</th>
#       <td id="T_eea0e_row11_col0" class="data row11 col0" >4455.625000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row12" class="row_heading level1 row12" >3</th>
#       <td id="T_eea0e_row12_col0" class="data row12 col0" >5998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row13" class="row_heading level1 row13" >4</th>
#       <td id="T_eea0e_row13_col0" class="data row13 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row14" class="row_heading level1 row14" >5</th>
#       <td id="T_eea0e_row14_col0" class="data row14 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level0_row15" class="row_heading level0 row15" rowspan="5">Manager</th>
#       <th id="T_eea0e_level1_row15" class="row_heading level1 row15" >1</th>
#       <td id="T_eea0e_row15_col0" class="data row15 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row16" class="row_heading level1 row16" >2</th>
#       <td id="T_eea0e_row16_col0" class="data row16 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row17" class="row_heading level1 row17" >3</th>
#       <td id="T_eea0e_row17_col0" class="data row17 col0" >12233.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row18" class="row_heading level1 row18" >4</th>
#       <td id="T_eea0e_row18_col0" class="data row18 col0" >16613.276596</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row19" class="row_heading level1 row19" >5</th>
#       <td id="T_eea0e_row19_col0" class="data row19 col0" >19183.976744</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level0_row20" class="row_heading level0 row20" rowspan="5">Manufacturing Director</th>
#       <th id="T_eea0e_level1_row20" class="row_heading level1 row20" >1</th>
#       <td id="T_eea0e_row20_col0" class="data row20 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_eea0e_row21_col0" class="data row21 col0" >5612.755556</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_eea0e_row22_col0" class="data row22 col0" >9307.044444</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row23" class="row_heading level1 row23" >4</th>
#       <td id="T_eea0e_row23_col0" class="data row23 col0" >13383.000000</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row24" class="row_heading level1 row24" >5</th>
#       <td id="T_eea0e_row24_col0" class="data row24 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level0_row25" class="row_heading level0 row25" rowspan="5">Research Director</th>
#       <th id="T_eea0e_level1_row25" class="row_heading level1 row25" >1</th>
#       <td id="T_eea0e_row25_col0" class="data row25 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row26" class="row_heading level1 row26" >2</th>
#       <td id="T_eea0e_row26_col0" class="data row26 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_eea0e_level1_row27" class="row_heading level1 row27" >3</th>
#       <td id="T_eea0e_row27_col0" class="data row27 col0" >12721.571429</td>
#     </tr>
#     <tr>
#       <th i

# %%
dados.groupby(["JobRole","JobLevel","Attrition"])["MonthlyIncome"].mean()
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\520409011.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dados.groupby(["JobRole","JobLevel","Attrition"])["MonthlyIncome"].mean()
# JobRole                    JobLevel  Attrition
# Healthcare Representative  1         No                   NaN
#                                      Yes                  NaN
#                            2         No           5828.280000
#                                      Yes          6792.000000
#                            3         No           9426.282051
#                                                      ...
# Sales Representative       3         Yes                  NaN
#                            4         No                   NaN
#                                      Yes                  NaN
#                            5         No                   NaN
#                                      Yes                  NaN
# Name: MonthlyIncome, Length: 90, dtype: float64

# %%
dados.pivot_table(index=["JobRole","JobLevel"], columns= "Attrition", values="MonthlyIncome").style.background_gradient(cmap="RdYlGn",axis="columns")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\4223679048.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index=["JobRole","JobLevel"], columns= "Attrition", values="MonthlyIncome").style.background_gradient(cmap="RdYlGn",axis="columns")
# <style type="text/css">
# #T_89498_row0_col0, #T_89498_row1_col1, #T_89498_row2_col1, #T_89498_row3_col1, #T_89498_row4_col0, #T_89498_row4_col1, #T_89498_row5_col0, #T_89498_row6_col1, #T_89498_row7_col0, #T_89498_row8_col1, #T_89498_row9_col0, #T_89498_row10_col0, #T_89498_row10_col1, #T_89498_row11_col0, #T_89498_row12_col1, #T_89498_row13_col0, #T_89498_row14_col0, #T_89498_row14_col1, #T_89498_row15_col0, #T_89498_row15_col1, #T_89498_row16_col0, #T_89498_row16_col1, #T_89498_row17_col0, #T_89498_row18_col1, #T_89498_row19_col1, #T_89498_row20_col0, #T_89498_row20_col1, #T_89498_row21_col0, #T_89498_row22_col0, #T_89498_row23_col0, #T_89498_row24_col1, #T_89498_row25_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_89498_row0_col1, #T_89498_row1_col0, #T_89498_row2_col0, #T_89498_row3_col0, #T_89498_row5_col1, #T_89498_row6_col0, #T_89498_row7_col1, #T_89498_row8_col0, #T_89498_row9_col1, #T_89498_row11_col1, #T_89498_row12_col0, #T_89498_row13_col1, #T_89498_row17_col1, #T_89498_row18_col0, #T_89498_row19_col0, #T_89498_row21_col1, #T_89498_row22_col1, #T_89498_row23_col1, #T_89498_row24_col0, #T_89498_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_89498">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_89498_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_89498_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89498_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_89498_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_89498_row0_col0" class="data row0 col0" >5828.280000</td>
#       <td id="T_89498_row0_col1" class="data row0 col1" >6792.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_89498_row1_col0" class="data row1 col0" >9426.282051</td>
#       <td id="T_89498_row1_col1" class="data row1 col1" >8877.800000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_89498_row2_col0" class="data row2 col0" >13073.500000</td>
#       <td id="T_89498_row2_col1" class="data row2 col1" >12169.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_89498_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_89498_row3_col0" class="data row3 col0" >2871.260870</td>
#       <td id="T_89498_row3_col1" class="data row3 col1" >2415.700000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_89498_row4_col0" class="data row4 col0" >5563.461538</td>
#       <td id="T_89498_row4_col1" class="data row4 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_89498_row5_col0" class="data row5 col0" >9326.500000</td>
#       <td id="T_89498_row5_col1" class="data row5 col1" >10216.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_89498_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_89498_row6_col0" class="data row6 col0" >2921.708333</td>
#       <td id="T_89498_row6_col1" class="data row6 col1" >2682.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_89498_row7_col0" class="data row7 col0" >4394.000000</td>
#       <td id="T_89498_row7_col1" class="data row7 col1" >5084.200000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_89498_row8_col0" class="data row8 col0" >6306.500000</td>
#       <td id="T_89498_row8_col1" class="data row8 col1" >5381.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_89498_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_89498_row9_col0" class="data row9 col0" >12133.700000</td>
#       <td id="T_89498_row9_col1" class="data row9 col1" >12729.500000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_89498_row10_col0" class="data row10 col0" >16613.276596</td>
#       <td id="T_89498_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_89498_row11_col0" class="data row11 col0" >19159.575000</td>
#       <td id="T_89498_row11_col1" class="data row11 col1" >19509.333333</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_89498_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_89498_row12_col0" class="data row12 col0" >5644.870588</td>
#       <td id="T_89498_row12_col1" class="data row12 col1" >5066.800000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_89498_row13_col0" class="data row13 col0" >9262.400000</td>
#       <td id="T_89498_row13_col1" class="data row13 col1" >9664.200000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_89498_row14_col0" class="data row14 col0" >13383.000000</td>
#       <td id="T_89498_row14_col1" class="data row14 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_89498_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_89498_row15_col0" class="data row15 col0" >12721.571429</td>
#       <td id="T_89498_row15_col1" class="data row15 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_89498_row16_col0" class="data row16 col0" >16429.038462</td>
#       <td id="T_89498_row16_col1" class="data row16 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_89498_row17_col0" class="data row17 col0" >19188.916667</td>
#       <td id="T_89498_row17_col1" class="data row17 col1" >19395.500000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_89498_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_89498_row18_col0" class="data row18 col0" >2859.455026</td>
#       <td id="T_89498_row18_col1" class="data row18 col1" >2694.066667</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_89498_row19_col0" class="data row19 col0" >4822.345455</td>
#       <td id="T_89498_row19_col1" class="data row19 col1" >4724.500000</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_89498_row20_col0" class="data row20 col0" >9724.000000</td>
#       <td id="T_89498_row20_col1" class="data row20 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_89498_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_89498_row21_col0" class="data row21 col0" >5760.218274</td>
#       <td id="T_89498_row21_col1" class="data row21 col1" >6023.416667</td>
#     </tr>
#     <tr>
#       <th id="T_89498_level1_row22" class="row_heading level1 row22" >3</th>

# %%
dados.pivot_table(
    index=["JobRole","JobLevel"], 
    columns= "Attrition", 
    values="MonthlyIncome",
    aggfunc=["mean","size"]
    )
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2042464896.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\2042464896.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1
# Healthcare Representative 1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Human Resources           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Laboratory Technician     4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Manager                   1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Manufacturing Director    1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Research Director         1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Research Scientist        4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Executive           1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Representative      3                  NaN           NaN    0   0
#                           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0

# %%
dados.pivot_table(
    index=["JobRole","JobLevel"], 
    columns= "Attrition", 
    values="MonthlyIncome",
    aggfunc=["mean","size"]
    ).dropna(how='all',subset=[("mean","No"),("mean","Yes")])
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\4069746708.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\4069746708.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1

# %%
dados.pivot_table(
    index=["JobRole","JobLevel"], 
    columns= "Attrition", 
    values="MonthlyIncome",
    aggfunc=["size"]
    )
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\575536794.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(
#                                    size
# Attrition                            No Yes
# JobRole                   JobLevel
# Healthcare Representative 1           0   0
#                           2          75   3
#                           3          39   5
#                           4           8   1
#                           5           0   0
# Human Resources           1          23  10
#                           2          13   0
#                           3           4   2
#                           4           0   0
#                           5           0   0
# Laboratory Technician     1         144  56
#                           2          51   5
#                           3           2   1
#                           4           0   0
#                           5           0   0
# Manager                   1           0   0
#                           2           0   0
#                           3          10   2
#                           4          47   0
#                           5          40   3
# Manufacturing Director    1           0   0
#                           2          85   5
#                           3          40   5
#                           4          10   0
#                           5           0   0
# Research Director         1           0   0
#                           2           0   0
#                           3          28   0
#                           4          26   0
#                           5          24   2
# Research Scientist        1         189  45
#                           2          55   2
#                           3           1   0
#                           4           0   0
#                           5           0   0
# Sales Executive           1           0   0
#                           2         197  36
#                           3          62  17
#                           4          10   4
#                           5           0   0
# Sales Representative      1          44  32
#                           2           6   1
#                           3           0   0
#                           4           0   0
#                           5           0   0

# %%
pd.crosstab([dados["JobRole"], dados["JobLevel"]],dados["Attrition"])
# Out:
# Attrition                            No  Yes
# JobRole                   JobLevel
# Healthcare Representative 2          75    3
#                           3          39    5
#                           4           8    1
# Human Resources           1          23   10
#                           2          13    0
#                           3           4    2
# Laboratory Technician     1         144   56
#                           2          51    5
#                           3           2    1
# Manager                   3          10    2
#                           4          47    0
#                           5          40    3
# Manufacturing Director    2          85    5
#                           3          40    5
#                           4          10    0
# Research Director         3          28    0
#                           4          26    0
#                           5          24    2
# Research Scientist        1         189   45
#                           2          55    2
#                           3           1    0
# Sales Executive           2         197   36
#                           3          62   17
#                           4          10    4
# Sales Representative      1          44   32
#                           2           6    1

# %%
pd.crosstab([dados["JobRole"], dados["JobLevel"]],dados["Attrition"],normalize="index").style.background_gradient(cmap="RdYlGn",axis="columns")
# Out:
# <style type="text/css">
# #T_b76d6_row0_col0, #T_b76d6_row1_col0, #T_b76d6_row2_col0, #T_b76d6_row3_col0, #T_b76d6_row4_col0, #T_b76d6_row5_col0, #T_b76d6_row6_col0, #T_b76d6_row7_col0, #T_b76d6_row8_col0, #T_b76d6_row9_col0, #T_b76d6_row10_col0, #T_b76d6_row11_col0, #T_b76d6_row12_col0, #T_b76d6_row13_col0, #T_b76d6_row14_col0, #T_b76d6_row15_col0, #T_b76d6_row16_col0, #T_b76d6_row17_col0, #T_b76d6_row18_col0, #T_b76d6_row19_col0, #T_b76d6_row20_col0, #T_b76d6_row21_col0, #T_b76d6_row22_col0, #T_b76d6_row23_col0, #T_b76d6_row24_col0, #T_b76d6_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b76d6_row0_col1, #T_b76d6_row1_col1, #T_b76d6_row2_col1, #T_b76d6_row3_col1, #T_b76d6_row4_col1, #T_b76d6_row5_col1, #T_b76d6_row6_col1, #T_b76d6_row7_col1, #T_b76d6_row8_col1, #T_b76d6_row9_col1, #T_b76d6_row10_col1, #T_b76d6_row11_col1, #T_b76d6_row12_col1, #T_b76d6_row13_col1, #T_b76d6_row14_col1, #T_b76d6_row15_col1, #T_b76d6_row16_col1, #T_b76d6_row17_col1, #T_b76d6_row18_col1, #T_b76d6_row19_col1, #T_b76d6_row20_col1, #T_b76d6_row21_col1, #T_b76d6_row22_col1, #T_b76d6_row23_col1, #T_b76d6_row24_col1, #T_b76d6_row25_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b76d6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_b76d6_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_b76d6_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b76d6_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_b76d6_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_b76d6_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_b76d6_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_b76d6_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_b76d6_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_b76d6_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_b76d6_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_b76d6_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_b76d6_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_b76d6_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_b76d6_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_b76d6_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_b76d6_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_b76d6_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_b76d6_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_b76d6_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_b76d6_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_b76d6_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_b76d6_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_b76d6_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_b76d6_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_b76d6_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_b76d6_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_b76d6_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_b76d6_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_b76d6_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_b76d6_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_b76d6_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_b76d6_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_b76d6_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_b76d6_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_b76d6_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_b76d6_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_b76d6_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_b76d6_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_b76d6_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_b76d6_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_b76d6_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_b76d6_row16_col0" class="data row16 col0" >1.000000</td>
#       <td id="T_b76d6_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_b76d6_row17_col0" class="data row17 col0" >0.923077</td>
#       <td id="T_b76d6_row17_col1" class="data row17 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_b76d6_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_b76d6_row18_col0" class="data row18 col0" >0.807692</td>
#       <td id="T_b76d6_row18_col1" class="data row18 col1" >0.192308</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_b76d6_row19_col0" class="data row19 col0" >0.964912</td>
#       <td id="T_b76d6_row19_col1" class="data row19 col1" >0.035088</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_b76d6_row20_col0" class="data row20 col0" >1.000000</td>
#       <td id="T_b76d6_row20_col1" class="data row20 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_b76d6_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_b76d6_row21_col0" class="data row21 col0" >0.845494</td>
#       <td id="T_b76d6_row21_col1" class="data row21 col1" >0.154506</td>
#     </tr>
#     <tr>
#       <th id="T_b76d6_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_b76d6_row22_col0" class="data row22 col0" >0.784810</td>
#       <td id="T_b76d6_row22

# %%
pd.crosstab([dados["JobRole"], dados["JobLevel"]],dados["Attrition"],normalize="index").style.background_gradient(cmap="RdYlGn",axis="columns",vmin=0,vmax=1)
# Out:
# <style type="text/css">
# #T_121ad_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_121ad_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_121ad_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_121ad_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_121ad_row2_col0, #T_121ad_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_121ad_row2_col1, #T_121ad_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_121ad_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_121ad_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_121ad_row4_col0, #T_121ad_row10_col0, #T_121ad_row14_col0, #T_121ad_row15_col0, #T_121ad_row16_col0, #T_121ad_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_121ad_row4_col1, #T_121ad_row10_col1, #T_121ad_row14_col1, #T_121ad_row15_col1, #T_121ad_row16_col1, #T_121ad_row20_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_121ad_row5_col0, #T_121ad_row8_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_121ad_row5_col1, #T_121ad_row8_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_121ad_row6_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_121ad_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_121ad_row7_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_121ad_row7_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_121ad_row9_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_121ad_row9_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_121ad_row11_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_121ad_row11_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_121ad_row12_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_121ad_row12_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_121ad_row17_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_121ad_row17_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_121ad_row18_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_121ad_row18_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_121ad_row19_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_121ad_row19_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_121ad_row21_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_121ad_row21_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_121ad_row22_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_121ad_row22_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_121ad_row23_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_121ad_row23_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_121ad_row24_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_121ad_row24_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_121ad_row25_col0 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_121ad_row25_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_121ad">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_121ad_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_121ad_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_121ad_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_121ad_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_121ad_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_121ad_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_121ad_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_121ad_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_121ad_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_121ad_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_121ad_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_121ad_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_121ad_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_121ad_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_121ad_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_121ad_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_121ad_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_121ad_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_121ad_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_121ad_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_121ad_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_121ad_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_121ad_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_121ad_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_121ad_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_121ad_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_121ad_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_121ad_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_121ad_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_121ad_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_121ad_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_121ad_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_121ad_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_121ad_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_121ad_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_121ad_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_121ad_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_121ad_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_121ad_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_121ad_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_121ad_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_121ad_level1_row16"

# %%
pd.crosstab(dados["Department"],dados["Gender"],margins=True,margins_name="Total")
# Out:
# Gender                  Female  Male  Total
# Department
# Human Resources             20    43     63
# Research & Development     379   582    961
# Sales                      189   257    446
# Total                      588   882   1470

# %%
dados.pivot_table(index=["Department","Gender"],columns="Attrition",aggfunc="size")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\1316067044.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index=["Department","Gender"],columns="Attrition",aggfunc="size")
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54

# %%
pd.crosstab(dados["JobRole"],dados["Gender"],margins=True,margins_name="Total")
# Out:
# Gender                     Female  Male  Total
# JobRole
# Healthcare Representative      51    80    131
# Human Resources                16    36     52
# Laboratory Technician          85   174    259
# Manager                        47    55    102
# Manufacturing Director         72    73    145
# Research Director              33    47     80
# Research Scientist            114   178    292
# Sales Executive               132   194    326
# Sales Representative           38    45     83
# Total                         588   882   1470

# %%
dados.pivot_table(index=["JobRole","Gender"],columns="Attrition",aggfunc="size")
# Out:
# C:\Users\kiwsley.costa\AppData\Local\Temp\ipykernel_9200\1517818482.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dados.pivot_table(index=["JobRole","Gender"],columns="Attrition",aggfunc="size")
# Attrition                          No  Yes
# JobRole                   Gender
# Healthcare Representative Female   46    5
#                           Male     76    4
# Human Resources           Female   10    6
#                           Male     30    6
# Laboratory Technician     Female   69   16
#                           Male    128   46
# Manager                   Female   45    2
#                           Male     52    3
# Manufacturing Director    Female   68    4
#                           Male     67    6
# Research Director         Female   32    1
#                           Male     46    1
# Research Scientist        Female   97   17
#                           Male    148   30
# Sales Executive           Female  112   20
#                           Male    157   37
# Sales Representative      Female   22   16
#                           Male     28   17

# %%
dados.groupby("Education")["MonthlyIncome"].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
mapemento_educacao = {
    1:"Below College",
    2:"College",
    3:"Bachelor",
    4:"Master",
    5:"PhD"
}

# %%
dados.groupby("Education")["MonthlyIncome"].mean().rename(index=mapemento_educacao)
# Out:
# Education
# Below College    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Master           6832.402010
# PhD              8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
dados.groupby("Education").size().rename(index=mapemento_educacao)
# Out:
# Education
# Below College    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
dados.groupby(["Education","Attrition"]).size().rename(index=mapemento_educacao)
# Out:
# Education      Attrition
# Below College  No           139
#                Yes           31
# College        No           238
#                Yes           44
# Bachelor       No           473
#                Yes           99
# Master         No           340
#                Yes           58
# PhD            No            43
#                Yes            5
# dtype: int64

# %%
pd.crosstab(dados["Education"],dados["Attrition"],margins=True,margins_name="Total").rename(index=mapemento_educacao)
# Out:
# Attrition        No  Yes  Total
# Education
# Below College   139   31    170
# College         238   44    282
# Bachelor        473   99    572
# Master          340   58    398
# PhD              43    5     48
# Total          1233  237   1470

# %%
pd.crosstab(
    dados["Education"],
    dados["Attrition"],
    margins=True,
    margins_name="Total",
    normalize="index",
    ).rename(index=mapemento_educacao)
# Out:
# Attrition            No       Yes
# Education
# Below College  0.817647  0.182353
# College        0.843972  0.156028
# Bachelor       0.826923  0.173077
# Master         0.854271  0.145729
# PhD            0.895833  0.104167
# Total          0.838776  0.161224

# %%
pd.crosstab(
    dados["Education"],
    dados["JobRole"],
    margins=True,
    margins_name="Total",
    normalize="columns"
    ).rename(index=mapemento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                      11.45             9.62
# College                            16.03            23.08
# Bachelor                           36.64            42.31
# Master                             33.59            19.23
# PhD                                 2.29             5.77
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  13.51     8.82                   10.34
# College                        22.01    18.63                   22.76
# Bachelor                       40.15    39.22                   37.24
# Master                         22.39    28.43                   26.21
# PhD                             1.93     4.90                    3.45
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               8.75               12.67             8.28
# College                    16.25               15.75            20.25
# Bachelor                   37.50               41.78            36.81
# Master                     28.75               27.05            30.98
# PhD                         8.75                2.74             3.68
#
# JobRole        Sales Representative  Total
# Education
# Below College                 24.10  11.56
# College                       18.07  19.18
# Bachelor                      38.55  38.91
# Master                        19.28  27.07
# PhD                            0.00   3.27

# %%
pd.crosstab(
    dados["Education"],
    dados["JobLevel"],
    margins=True,
    margins_name="Total",
    normalize="columns"
    ).rename(index=mapemento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4      5  Total
# Education
# Below College  16.39   8.80   9.17   7.55   8.70  11.56
# College        17.31  23.41  15.14  16.04  18.84  19.18
# Bachelor       42.54  32.02  44.95  41.51  40.58  38.91
# Master         22.28  32.02  26.61  26.42  28.99  27.07
# PhD             1.47   3.75   4.13   8.49   2.90   3.27

# %%
pd.crosstab(
    [dados["JobRole"],dados["Education"],dados["Attrition"]],
    dados["Education"],
    margins=True,
    margins_name="Total",
    ).rename(columns=mapemento_educacao)
# Out:
# Education                                      Below College  College  \
# JobRole                   Education Attrition
# Healthcare Representative 1         No                    13        0
#                                     Yes                    2        0
#                           2         No                     0       18
#                                     Yes                    0        3
#                           3         No                     0        0
# ...                                                      ...      ...
# Sales Representative      3         No                     0        0
#                                     Yes                    0        0
#                           4         No                     0        0
#                                     Yes                    0        0
# Total                                                    170      282
#
# Education                                      Bachelor  Master  PhD  Total
# JobRole                   Education Attrition
# Healthcare Representative 1         No                0       0    0     13
#                                     Yes               0       0    0      2
#                           2         No                0       0    0     18
#                                     Yes               0       0    0      3
#                           3         No               45       0    0     45
# ...                                                 ...     ...  ...    ...
# Sales Representative      3         No               16       0    0     16
#                                     Yes              16       0    0     16
#                           4         No                0      13    0     13
#                                     Yes               0       3    0      3
# Total                                               572     398   48   1470
#
# [82 rows x 6 columns]

# %%
import pandas as pd

dados_triagem = './dados/triagem_medica.csv'


df_triagem= pd.read_csv(dados_triagem)

df_triagem
# Out:
#             nome       setor  idade  salario  peso  altura horario_de_entrada  \
# 0     João Silva          TI     28     7800    90    1.82              08:00
# 1    Maria Souza      Vendas     31     3500    60    1.55              07:55
# 2    José Araújo          TI     25     8000    82    1.70              08:01
# 3     Ana Dantas  Financeiro     40     6000    70    1.74              08:30
# 4   Carlos Alves          RH     55     3000    65    1.62              07:53
# 5     Tadeu Lima          TI     30     7500    75    1.80              08:10
# 6    Marta Costa      Vendas     35     4000    55    1.60              08:05
# 7   Pedro Barros  Financeiro     45     5000    78    1.78              08:20
# 8  Lucas Cardoso          TI     27     7000    85    1.75              08:02
# 9   Sandra Gomes          RH     50     3200    62    1.58              07:45
#
#    temperatura_corporal  pressao_arterial_sistolica  \
# 0                  36.5                         120
# ...

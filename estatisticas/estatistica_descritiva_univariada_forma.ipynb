# %% [markdown]
# # Estatística descritiva univariada

# %% [markdown]
# ## Medidas-resumo usuais em estatística descritiva univariada

# %% [markdown]
# ### Medidas de forma

# %% [markdown]
# As medidas de assimetria (*skewness*) e curtose (*kurtosis*) são utilizadas para descrever a forma da distribuição dos dados.
#
# As medidas de assimetria referem-se à forma da curva de uma distribuição de frequências.

# %% [markdown]
# ![screenshot](https://upload.wikimedia.org/wikipedia/commons/c/cc/Relationship_between_mean_and_median_under_different_skewness.png)

# %% [markdown]
# Existem diversas fórmulas para calcular assimetria. No nosso caso, mais importante do que a fórmula é a interpretação do valor obtido. Se a assimetria for zero, a distribuição é simétrica. Se a assimetria for positiva, a distribuição é assimétrica à direita, ou seja, a cauda direita é mais longa. Se a assimetria for negativa, a distribuição é assimétrica à esquerda, ou seja, a cauda esquerda é mais longa.

# %% [markdown]
# A curtose pode ser definida como o grau de achatamento de uma distribuição de frequências (altura do pico da curva) em relação a uma distribuição teórica que geralmente corresponde à distribuição normal.
#
# Existem diversas fórmulas para calcular curtose. No nosso caso, mais importante do que a fórmula é a interpretação do valor obtido. Se a curtose for zero (**considerando a fórmula por trás do método do Pandas!**), a distribuição é mesocúrtica, ou seja, tem o mesmo achatamento da distribuição normal. Se a curtose for positiva, a distribuição é leptocúrtica, ou seja, tem um pico mais alto e caudas mais pesadas do que a distribuição normal. Se a curtose for negativa, a distribuição é platicúrtica, ou seja, tem um pico mais baixo e caudas mais leves do que a distribuição normal.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.kurtosis.html

# %% [markdown]
# ![curtose.png](attachment:f935ccac-357d-43a9-baec-87872bdb7b7e.png)

# %%
import pandas as pd

DADOS = "./dados/carrots.csv"

df_cenouras = pd.read_csv(DADOS)

df_cenouras.head()
# Out:
#    carrots
# 0     45.0
# 1     44.5
# 2     44.0
# 3     45.0
# 4     46.5

# %%
from auxiliares import composicao_histograma

composicao_histograma(df_cenouras,"carrots")

# %%
df_cenouras.skew()
# Out:
# carrots    0.161368
# dtype: float64

# %%
df_cenouras.kurtosis()
# Out:
# carrots   -0.935288
# dtype: float64

# %%
DADOS = "./dados/grades.csv"

df_notas = pd.read_csv(DADOS)

df_notas.head()
# Out:
#    grades
# 0     4.2
# 1     3.9
# 2     5.7
# 3     6.5
# 4     4.6

# %%
composicao_histograma(df_notas,"grades")

# %%
df_notas.skew()
# Out:
# grades    0.421415
# dtype: float64

# %%
df_notas.kurtosis()
# Out:
# grades   -0.413421
# dtype: float64
